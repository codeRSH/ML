# %%
# Import Packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# Read the Pizza1 file
data = pd.read_csv("pizza1.csv")
print(data)
# Out:
# brand     id   mois   prot    fat   ash  sodium   carb   cal
# 0       A  14069  27.82  21.43  44.87  5.11    1.77   0.77  4.93
# 1       A  14053    NaN  21.26    NaN  5.34    1.79   1.02  4.84
# 2       A  14025    NaN  19.99    NaN  5.08    1.63   0.80  4.95
# 3       A  14016    NaN  20.15    NaN  4.79    1.61   1.38  4.74
# 4       A  14005  30.49  21.28    NaN  4.82    1.64   1.76  4.67
# ..    ...    ...    ...    ...    ...   ...     ...    ...   ...
# 295     J  34044  44.91  11.07  17.00  2.49    0.66  25.36  2.91
# 296     J  24069  43.15  11.79  18.46  2.43    0.67  24.17  3.10
# 297     J  34039  44.55  11.01  16.03  2.43    0.64  25.98  2.92
# 298     J  14044  47.60  10.43  15.18  2.32    0.56  24.47  2.76
# 299     J  14045  46.84   9.91  15.50  2.27    0.57  25.48  2.81
#
# [300 rows x 9 columns]

# %%
data.isnull().sum()
# Out:
# brand     0
# id        0
# mois      3
# prot      0
# fat       4
# ash       0
# sodium    0
# carb      0
# cal       0
# dtype: int64

# %%
data.shape
# Out:
#      brand     id   mois   prot    fat    ash  sodium   carb    cal
# 0    False  False  False  False  False  False   False  False  False
# 1    False  False   True  False   True  False   False  False  False
# 2    False  False   True  False   True  False   False  False  False
# 3    False  False   True  False   True  False   False  False  False
# 4    False  False  False  False   True  False   False  False  False
# ..     ...    ...    ...    ...    ...    ...     ...    ...    ...
# 295  False  False  False  False  False  False   False  False  False
# 296  False  False  False  False  False  False   False  False  False
# 297  False  False  False  False  False  False   False  False  False
# 298  False  False  False  False  False  False   False  False  False
# 299  False  False  False  False  False  False   False  False  False
#
# [300 rows x 9 columns]

# %%
# Drop the rows with null value

data1 = data.dropna()
data1.shape
# Out:
# (296, 9)

# %%
# Replace NAN values by their respective column mean

data2 = data.fillna(data.mean())
data2.isnull().sum()
# Out:
# brand     0
# id        0
# mois      0
# prot      0
# fat       0
# ash       0
# sodium    0
# carb      0
# cal       0
# dtype: int64

# %%
data.head()
# Out:
#   brand     id   mois   prot    fat   ash  sodium  carb   cal
# 0     A  14069  27.82  21.43  44.87  5.11    1.77  0.77  4.93
# 1     A  14053    NaN  21.26    NaN  5.34    1.79  1.02  4.84
# 2     A  14025    NaN  19.99    NaN  5.08    1.63  0.80  4.95
# 3     A  14016    NaN  20.15    NaN  4.79    1.61  1.38  4.74
# 4     A  14005  30.49  21.28    NaN  4.82    1.64  1.76  4.67

# %%
data2.head()
# Out:
#   brand     id       mois   prot        fat   ash  sodium  carb   cal
# 0     A  14069  27.820000  21.43  44.870000  5.11    1.77  0.77  4.93
# 1     A  14053  41.021987  21.26  19.913547  5.34    1.79  1.02  4.84
# 2     A  14025  41.021987  19.99  19.913547  5.08    1.63  0.80  4.95
# 3     A  14016  41.021987  20.15  19.913547  4.79    1.61  1.38  4.74
# 4     A  14005  30.490000  21.28  19.913547  4.82    1.64  1.76  4.67

# %%
# Replace NAN values by their respective column median

data3 = data.fillna(data.median())
data3.head()
# Out:
#   brand     id   mois   prot     fat   ash  sodium  carb   cal
# 0     A  14069  27.82  21.43  44.870  5.11    1.77  0.77  4.93
# 1     A  14053  43.80  21.26  17.035  5.34    1.79  1.02  4.84
# 2     A  14025  43.80  19.99  17.035  5.08    1.63  0.80  4.95
# 3     A  14016  43.80  20.15  17.035  4.79    1.61  1.38  4.74
# 4     A  14005  30.49  21.28  17.035  4.82    1.64  1.76  4.67

# %%
data4 = data.fillna(0)
data4.head()
# Out:
#   brand     id   mois   prot    fat   ash  sodium  carb   cal
# 0     A  14069  27.82  21.43  44.87  5.11    1.77  0.77  4.93
# 1     A  14053   0.00  21.26   0.00  5.34    1.79  1.02  4.84
# 2     A  14025   0.00  19.99   0.00  5.08    1.63  0.80  4.95
# 3     A  14016   0.00  20.15   0.00  4.79    1.61  1.38  4.74
# 4     A  14005  30.49  21.28   0.00  4.82    1.64  1.76  4.67

# %%
# Dealing with Column Reduction

# Dropping correlated columns

corr_matrix = data3.corr()
corr_matrix
# Out:
#               id      mois      prot       fat       ash    sodium      carb  \
# id      1.000000  0.017658 -0.076485  0.035574 -0.034072 -0.015156  0.014966
# mois    0.017658  1.000000  0.380062 -0.135866  0.297474 -0.060697 -0.614969
# prot   -0.076485  0.380062  1.000000  0.475365  0.823844  0.429130 -0.853542
# fat     0.035574 -0.135866  0.475365  1.000000  0.752413  0.866936 -0.621653
# ash    -0.034072  0.297474  0.823844  0.752413  1.000000  0.808122 -0.898988
# sodium -0.015156 -0.060697  0.429130  0.866936  0.808122  1.000000 -0.620176
# carb    0.014966 -0.614969 -0.853542 -0.621653 -0.898988 -0.620176  1.000000
# cal    -0.021209 -0.730616  0.070258  0.699088  0.326468  0.671958 -0.023485
#
#              cal
# id     -0.021209
# mois   -0.730616
# prot    0.070258
# fat     0.699088
# ash     0.326468
# sodium  0.671958
# carb   -0.023485
# cal     1.000000

# %%
# Visualizing the correlation matrix

sb.heatmap(corr_matrix, annot = True)
plt.show()

# %%
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k = 1).astype(np.bool))
upper
# Out:
#         id      mois      prot       fat       ash    sodium      carb  \
# id     NaN  0.017658 -0.076485  0.035574 -0.034072 -0.015156  0.014966
# mois   NaN       NaN  0.380062 -0.135866  0.297474 -0.060697 -0.614969
# prot   NaN       NaN       NaN  0.475365  0.823844  0.429130 -0.853542
# fat    NaN       NaN       NaN       NaN  0.752413  0.866936 -0.621653
# ash    NaN       NaN       NaN       NaN       NaN  0.808122 -0.898988
# sodium NaN       NaN       NaN       NaN       NaN       NaN -0.620176
# carb   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# cal    NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#              cal
# id     -0.021209
# mois   -0.730616
# prot    0.070258
# fat     0.699088
# ash     0.326468
# sodium  0.671958
# carb   -0.023485
# cal          NaN

# %%
# Find columns which have correlation of greater than 0.7
drp = [column for column in upper.columns if any(upper[column] > 0.70)]
drp
# Out:
# ['ash', 'sodium']

# %%
data5 = data3.drop(data[drp], axis = 1)

data5
# Out:
#     brand     id   mois   prot     fat   carb   cal
# 0       A  14069  27.82  21.43  44.870   0.77  4.93
# 1       A  14053  43.80  21.26  17.035   1.02  4.84
# 2       A  14025  43.80  19.99  17.035   0.80  4.95
# 3       A  14016  43.80  20.15  17.035   1.38  4.74
# 4       A  14005  30.49  21.28  17.035   1.76  4.67
# ..    ...    ...    ...    ...     ...    ...   ...
# 295     J  34044  44.91  11.07  17.000  25.36  2.91
# 296     J  24069  43.15  11.79  18.460  24.17  3.10
# 297     J  34039  44.55  11.01  16.030  25.98  2.92
# 298     J  14044  47.60  10.43  15.180  24.47  2.76
# 299     J  14045  46.84   9.91  15.500  25.48  2.81
#
# [300 rows x 7 columns]

# %%
# Implement PCA for Dimension Reduction

# Reading the datasets

dataset = pd.read_csv("Wine.csv")

# %%
dataset.head(5)
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Customer_Segment
# 0   3.92     1065                 1
# ...

# %%
# Create a dataframe of Independent and Dependent variables. 

x = dataset.loc[:, 'Alcohol':'Proline']
x
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
y = dataset.loc[:, 'Customer_Segment']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Customer_Segment, Length: 178, dtype: int64

# %%
# Preprocess the dataset standardize the dataset

from sklearn import preprocessing

sc = preprocessing.StandardScaler().fit(x)
sc
# Out:
# StandardScaler()

# %%
sc.mean_
# Out:
# array([1.30006180e+01, 2.33634831e+00, 2.36651685e+00, 1.94949438e+01,
#        9.97415730e+01, 2.29511236e+00, 2.02926966e+00, 3.61853933e-01,
#        1.59089888e+00, 5.05808988e+00, 9.57449438e-01, 2.61168539e+00,
#        7.46893258e+02])

# %%
sc.scale_
# Out:
# array([8.09542915e-01, 1.11400363e+00, 2.73572294e-01, 3.33016976e+00,
#        1.42423077e+01, 6.24090564e-01, 9.96048950e-01, 1.24103260e-01,
#        5.70748849e-01, 2.31176466e+00, 2.27928607e-01, 7.07993265e-01,
#        3.14021657e+02])

# %%
x = sc.transform(x)
x
# Out:
# array([[-14.18331904,  -2.6019647 ,  -7.80219473, ...,  -2.6116606 ,
#          -1.07877555,  -2.37525098],
#        [-15.75497496,  -2.54555876, -11.67703471, ...,  -2.41917319,
#          -2.1161728 ,  -2.3754031 ],
#        [-15.81601015,  -2.07819527,  -4.5954306 , ...,  -2.80414801,
#          -2.57502158,  -2.37403406],
#        ...,
#        [-15.6481634 ,  -0.53106095, -10.07365265, ..., -11.27359406,
#          -5.78696306,  -2.37758341],
#        [-15.80075135,  -1.89286147,  -8.60388576, ..., -11.08110665,
#          -5.66726338,  -2.37753271],
#        [-14.335907  ,  -0.6761048 ,  -3.6601244 , ..., -10.88861924,
#          -5.70716327,  -2.38037219]])

# %%
from sklearn.decomposition import PCA

pca = PCA()

results = pca.fit(x)

# %%
Z = results.transform(x)
Z
# Out:
# array([[-6.03082345e+00,  1.07853259e+00, -1.86731316e+00, ...,
#         -1.58580388e-01,  1.03344606e-01, -1.69752407e-03],
#        [-7.22683247e+00,  3.22168602e-01,  2.34390891e+00, ...,
#         -4.65644156e-01,  8.18269644e-03,  4.60325944e-04],
#        [-4.38946630e+00,  1.30105437e+00, -4.79529626e+00, ...,
#         -1.70101042e-01, -5.45390431e-02,  2.13770483e-03],
#        ...,
#        [ 6.12597037e+00, -6.55966239e+00,  1.70150020e+00, ...,
#         -1.25985091e-02,  1.03108656e-01,  8.77781603e-04],
#        [ 1.23366222e+01, -4.54873248e+00,  8.03458788e-01, ...,
#         -8.71889883e-02,  1.05642214e-01,  8.47154581e-04],
#        [ 1.45867079e+01, -3.75247999e+00, -4.14922296e+00, ...,
#          1.94080827e-01, -3.54247624e-02, -2.11822572e-03]])

# %%
plt.plot(results.explained_variance_ratio_ * 100)

# %%
plt.show()
